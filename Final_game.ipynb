# %% [markdown]
# ## importing

# %%
# !pip install random2
# Out:
# Requirement already satisfied: random2 in c:\users\sayan\anaconda3\lib\site-packages (1.0.1)

# %%
import random as rd

# %%
chance,Round,Range=40,5,100
count_chance,count_round=1,1

# %%
while (count_round<=Round):
    print(f'Round {count_round}')
    print(f'Range=(0,{Range}), you have {chance} chances.\n')
    
    comp_num=rd.randint(1,Range)
    
    while (count_chance<=chance):
        your_num=int(input("\nChoose a number: "))
        
        if(your_num!=comp_num):
            print(f'\nYou have {chance-count_chance} chance left.')
            if(your_num>comp_num): print("you choose a higher number.")
            else: print("you choose a lower number.")
            
            count_chance+=1
        else:
            print(f'\nYou win round {count_round}, with {count_chance} steps.')
            count_round+=1
            chance//=2
            count_chance=1
            Range-=20
            
            if(count_round<=Round): print(f'\n\nYou are promoted to round {count_round}.\n\n\n\n')
            else: print('\n\n\nWohhhhoooo..... You win the match.....')
            break
    if(count_chance>chance):
        print(f'\n\n\nYou lose the match. the number is {comp_num}')
        break
# Out:
# Round 1
# Range=(0,100), you have 40 chances.
#
#
# Choose a number: 100
#
# You have 39 chance left.
# you choose a higher number.
#
# Choose a number: 90
#
# You have 38 chance left.
# you choose a higher number.
#
# Choose a number: 50
#
# You have 37 chance left.
# you choose a higher number.
#
# Choose a number: 20
#
# You have 36 chance left.
# you choose a lower number.
#
# Choose a number: 30
#
# You have 35 chance left.
# you choose a higher number.
#
# Choose a number: 25
#
# You have 34 chance left.
# you choose a higher number.
#
# Choose a number: 21
#
# You have 33 chance left.
# you choose a lower number.
#
# Choose a number: 23
#
# You have 32 chance left.
# you choose a lower number.
#
# Choose a number: 24
#
# You win round 1, with 9 steps.
#
#
# You are promoted to round 2.
#
#
#
#
# Round 2
# Range=(0,80), you have 20 chances.
#
#
# Choose a number: 80
#
# You have 19 chance left.
# you choose a higher number.
#
# Choose a number: 50
#
# You have 18 chance left.
# you choose a lower number.
#
# Choose a number: 70
#
# You have 17 chance left.
# you choose a lower number.
#
# Choose a number: 75
#
# You have 16 chance left.
# you choose a higher number.
#
# Choose a number: 73
#
# You have 15 chance left.
# you choose a higher number.
#
# Choose a number: 71
#
# You win round 2, with 6 steps.
#
#
# You are promoted to round 3.
#
#
#
#
# Round 3
# Range=(0,60), you have 10 chances.
#
#
# Choose a number: 60
#
# You have 9 chance left.
# you choose a higher number.
#
# Choose a number: 20
#
# You have 8 chance left.
# you choose a higher number.
#
# Choose a number: 5
#
# You have 7 chance left.
# you choose a higher number.
#
# Choose a number: 2
#
# You win round 3, with 4 steps.
#
#
# You are promoted to round 4.
#
#
#
#
# Round 4
# Range=(0,40), you have 5 chances.
#
#
# Choose a number: 20
#
# You have 4 chance left.
# you choose a lower number.
#
# Choose a number: 30
#
# You have 3 chance left.
# you choose a higher number.
#
# Choose a number: 23
#
# You have 2 chance left.
# you choose a lower number.
#
# Choose a number: 26
#
# You have 1 chance left.
# you choose a higher number.
#
# Choose a number: 25
#
# You have 0 chance left.
# you choose a higher number.
#
#
#
# You lose the match. the number is 24
